# %% [markdown]
# ## Attention 신경망 구현 및 학습

# %%
import random
import tensorflow as tf
from konlpy.tag import Okt

# %% [markdown]
# ## 하이퍼 파라미터

# %%
EPOCHS = 200
NUM_WORDS = 2000

# %% [markdown]
# ## Encoder

# %%
class Encoder(tf.keras.Model):
    def __init__(self):
        super(Encoder, self).__init__()
        self.emb = tf.keras.layers.Embedding(NUM_WORDS, 64)
#         self.lstm = tf.keras.layers.LSTM(512, return_state=True)
        self.lstm = tf.keras.layers.LSTM(512, return_sequences=True, return_state=True)

    def call(self, x, training=False, mask=None):
        x = self.emb(x)
#         _, h, c = self.lstm(x)
        H, h, c = self.lstm(x)
#         return h, c
        return H, h, c

# %% [markdown]
# ## Decoder

# %%
class Decoder(tf.keras.Model):
    def __init__(self):
        super(Decoder, self).__init__()
        self.emb = tf.keras.layers.Embedding(NUM_WORDS, 64)
        self.lstm = tf.keras.layers.LSTM(512, return_sequences=True, return_state=True)
        self.att = tf.keras.layers.Attention()
        self.dense = tf.keras.layers.Dense(NUM_WORDS, activation='softmax')

    def call(self, inputs, training=False, mask=None):
#         x, h, c = inputs
        x, s0, c0, H = inputs
        x = self.emb(x)
#         x, h, c = self.lstm(x, initial_state=[h, c])
        S, h, c = self.lstm(x, initial_state=[s0, c0])
        
        S_ = tf.concat([s0[:, tf.newaxis, :], S[:, :-1, :]], axis=1)
        A = self.att([S_, H])
        y = tf.concat([S, A], axis=-1)
        
        return self.dense(y), h, c

# %% [markdown]
# ## Seq2seq

# %%
class Seq2seq(tf.keras.Model):
    def __init__(self, sos, eos):
        super(Seq2seq, self).__init__()
        self.enc = Encoder()
        self.dec = Decoder()
        self.sos = sos
        self.eos = eos

    def call(self, inputs, training=False, mask=None):
        if training is True:
            x, y = inputs
#             h, c = self.enc(x)
            H, h, c = self.enc(x)
#             y, _, _ = self.dec((y, h, c))
            y, _, _ = self.dec((y, h, c, H))
            return y
        else:
            x = inputs
#             h, c = self.enc(x)
            H, h, c = self.enc(x)
            y = tf.convert_to_tensor(self.sos)
            y = tf.reshape(y, (1, 1))

            seq = tf.TensorArray(tf.int32, 64)

            for idx in tf.range(64):
#                 y, h, c = self.dec([y, h, c])
                y, h, c = self.dec([y, h, c, H])
                y = tf.cast(tf.argmax(y, axis=-1), dtype=tf.int32)
                y = tf.reshape(y, (1, 1))
                seq = seq.write(idx, y)

                if y == self.eos:
                    break

            return tf.reshape(seq.stack(), (1, 64))

# %% [markdown]
# ## 학습, 테스트 루프 정의

# %%
# Implement training loop
@tf.function
def train_step(model, inputs, labels, loss_object, optimizer, train_loss, train_accuracy):
    output_labels = labels[:, 1:]
    shifted_labels = labels[:, :-1]
    with tf.GradientTape() as tape:
        predictions = model([inputs, shifted_labels], training=True)
        loss = loss_object(output_labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    train_loss(loss)
    train_accuracy(output_labels, predictions)

# Implement algorithm test
@tf.function
def test_step(model, inputs):
    return model(inputs, training=False)

# %% [markdown]
# ## 데이터셋 준비

# %%
dataset_file = 'chatbot_data.csv'  # acquired from 'http://www.aihub.or.kr' and modified
okt = Okt()

with open(dataset_file, 'r') as file:
    lines = file.readlines()
    seq = [' '.join(okt.morphs(line)) for line in lines]

questions = seq[::2]
answers = ['\t ' + lines for lines in seq[1::2]]

num_sample = len(questions)

perm = list(range(num_sample))
random.seed(0)
random.shuffle(perm)

train_q = list()
train_a = list()
test_q = list()
test_a = list()

for idx, qna in enumerate(zip(questions, answers)):
    q, a = qna
    if perm[idx] > num_sample//5:
        train_q.append(q)
        train_a.append(a)
    else:
        test_q.append(q)
        test_a.append(a)

tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=NUM_WORDS,
                                                  filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~')

tokenizer.fit_on_texts(train_q + train_a)

train_q_seq = tokenizer.texts_to_sequences(train_q)
train_a_seq = tokenizer.texts_to_sequences(train_a)

test_q_seq = tokenizer.texts_to_sequences(test_q)
test_a_seq = tokenizer.texts_to_sequences(test_a)

x_train = tf.keras.preprocessing.sequence.pad_sequences(train_q_seq,
                                                        value=0,
                                                        padding='pre',
                                                        maxlen=64)
y_train = tf.keras.preprocessing.sequence.pad_sequences(train_a_seq,
                                                        value=0,
                                                        padding='post',
                                                        maxlen=65)


x_test = tf.keras.preprocessing.sequence.pad_sequences(test_q_seq,
                                                       value=0,
                                                       padding='pre',
                                                       maxlen=64)
y_test = tf.keras.preprocessing.sequence.pad_sequences(test_a_seq,
                                                       value=0,
                                                       padding='post',
                                                       maxlen=65)

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(10000).batch(32).prefetch(1024)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(1).prefetch(1024)

# %% [markdown]
# ## 학습 환경 정의
# ### 모델 생성, 손실함수, 최적화 알고리즘, 평가지표 정의

# %%
# Create model
model = Seq2seq(sos=tokenizer.word_index['\t'],
                eos=tokenizer.word_index['\n'])

# Define loss and optimizer
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()

# Define performance metrics
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

# %% [markdown]
# ## 학습 루프 동작

# %%
for epoch in range(EPOCHS):
    for seqs, labels in train_ds:
        train_step(model, seqs, labels, loss_object, optimizer, train_loss, train_accuracy)

    template = 'Epoch {}, Loss: {}, Accuracy: {}'
    print(template.format(epoch + 1,
                          train_loss.result(),
                          train_accuracy.result() * 100))

    train_loss.reset_states()
    train_accuracy.reset_states()
# Out:
# Epoch 1, Loss: 2.900367259979248, Accuracy: 83.09837341308594
# Epoch 2, Loss: 0.6559760570526123, Accuracy: 90.47618865966797
# Epoch 3, Loss: 0.5864062309265137, Accuracy: 90.73856353759766
# Epoch 4, Loss: 0.562481164932251, Accuracy: 90.9774398803711
# Epoch 5, Loss: 0.5419784784317017, Accuracy: 91.1536636352539
# Epoch 6, Loss: 0.5414578318595886, Accuracy: 91.23981475830078
# Epoch 7, Loss: 0.528222918510437, Accuracy: 91.29072570800781
# Epoch 8, Loss: 0.5207951068878174, Accuracy: 91.22806549072266
# Epoch 9, Loss: 0.5076488256454468, Accuracy: 91.25547790527344
# Epoch 10, Loss: 0.49626585841178894, Accuracy: 91.39253997802734
# Epoch 11, Loss: 0.48538830876350403, Accuracy: 91.59618377685547
# Epoch 12, Loss: 0.4676087200641632, Accuracy: 91.94862365722656
# Epoch 13, Loss: 0.45081254839897156, Accuracy: 92.15617370605469
# Epoch 14, Loss: 0.4437231719493866, Accuracy: 92.31281280517578
# Epoch 15, Loss: 0.44498109817504883, Accuracy: 92.4420394897461
# Epoch 16, Loss: 0.4311754107475281, Accuracy: 92.50077819824219
# Epoch 17, Loss: 0.42601948976516724, Accuracy: 92.55560302734375
# Epoch 18, Loss: 0.4213530123233795, Accuracy: 92.6378402709961
# Epoch 19, Loss: 0.41650694608688354, Accuracy: 92.65350341796875
# Epoch 20, Loss: 0.4089207649230957, Accuracy: 92.72007751464844
# Epoch 21, Loss: 0.4028450548648834, Accuracy: 92.79056549072266
# Epoch 22, Loss: 0.40165454149246216, Accuracy: 92.87672424316406
# Epoch 23, Loss: 0.3902336359024048, Accuracy: 92.89238739013672
# Epoch 24, Loss: 0.3894272446632385, Accuracy: 92.92371368408203
# Epoch 25, Loss: 0.38241320848464966, Accuracy: 93.00203704833984
# Epoch 26, Loss: 0.37992411851882935, Accuracy: 92.99812316894531
# Epoch 27, Loss: 0.37252333760261536, Accuracy: 93.08818817138672
# Epoch 28, Loss: 0.36993423104286194, Accuracy: 93.14693450927734
# Epoch 29, Loss: 0.3660898208618164, Accuracy: 93.19001007080078
# Epoch 30, Loss: 0.3621559143066406, Accuracy: 93.19783782958984
# Epoch 31, Loss: 0.35278961062431335, Accuracy: 93.23308563232422
# Epoch 32, Loss: 0.3474513292312622, Accuracy: 93.30748748779297
# Epoch 33, Loss: 0.34645599126815796, Accuracy: 93.28007507324219
# Epoch 34, Loss: 0.3437272310256958, Accuracy: 93.34273529052734
# Epoch 35, Loss: 0.3378346562385559, Accuracy: 93.37014770507812
# Epoch 36, Loss: 0.3335188329219818, Accuracy: 93.456298828125
# Epoch 37, Loss: 0.3315987288951874, Accuracy: 93.40930938720703
# Epoch 38, Loss: 0.3243001401424408, Accuracy: 93.48762512207031
# Epoch 39, Loss: 0.31985729932785034, Accuracy: 93.57769775390625
# Epoch 40, Loss: 0.3185161352157593, Accuracy: 93.6129379272461
# Epoch 41, Loss: 0.3110244870185852, Accuracy: 93.63643646240234
# Epoch 42, Loss: 0.30305132269859314, Accuracy: 93.68342590332031
# Epoch 43, Loss: 0.3020937740802765, Accuracy: 93.71475219726562
# Epoch 44, Loss: 0.29906532168388367, Accuracy: 93.77349853515625
# Epoch 45, Loss: 0.28943029046058655, Accuracy: 93.91838836669922
# Epoch 46, Loss: 0.28621992468833923, Accuracy: 93.9066390991211
# Epoch 47, Loss: 0.2867649495601654, Accuracy: 93.94188690185547
# Epoch 48, Loss: 0.27632007002830505, Accuracy: 94.00846099853516
# Epoch 49, Loss: 0.2704867720603943, Accuracy: 94.0828628540039
# Epoch 50, Loss: 0.2682870626449585, Accuracy: 94.16510009765625
# Epoch 51, Loss: 0.2605496048927307, Accuracy: 94.21208953857422
# Epoch 52, Loss: 0.2549975514411926, Accuracy: 94.32173919677734
# Epoch 53, Loss: 0.25317147374153137, Accuracy: 94.37265014648438
# Epoch 54, Loss: 0.2506009340286255, Accuracy: 94.50187683105469
# Epoch 55, Loss: 0.24411259591579437, Accuracy: 94.63502502441406
# Epoch 56, Loss: 0.24011032283306122, Accuracy: 94.57628631591797
# Epoch 57, Loss: 0.2342744618654251, Accuracy: 94.76817321777344
# Epoch 58, Loss: 0.2256651222705841, Accuracy: 94.90131378173828
# Epoch 59, Loss: 0.22230897843837738, Accuracy: 95.06970977783203
# Epoch 60, Loss: 0.2179766297340393, Accuracy: 95.12844848632812
# Epoch 61, Loss: 0.2141193449497223, Accuracy: 95.14019775390625
# Epoch 62, Loss: 0.2061869502067566, Accuracy: 95.28117370605469
# Epoch 63, Loss: 0.20322617888450623, Accuracy: 95.44172668457031
# Epoch 64, Loss: 0.19670766592025757, Accuracy: 95.60228729248047
# Epoch 65, Loss: 0.19302599132061005, Accuracy: 95.68452453613281
# Epoch 66, Loss: 0.1843658834695816, Accuracy: 95.82941436767578
# Epoch 67, Loss: 0.18071132898330688, Accuracy: 95.96256256103516
# Epoch 68, Loss: 0.1746872216463089, Accuracy: 96.1427001953125
# Epoch 69, Loss: 0.16961438953876495, Accuracy: 96.27584838867188
# Epoch 70, Loss: 0.16376057267189026, Accuracy: 96.39332580566406
# Epoch 71, Loss: 0.1578405797481537, Accuracy: 96.53430938720703
# Epoch 72, Loss: 0.15437565743923187, Accuracy: 96.64787292480469
# Epoch 73, Loss: 0.14810766279697418, Accuracy: 96.82801055908203
# Epoch 74, Loss: 0.1394834667444229, Accuracy: 96.90241241455078
# Epoch 75, Loss: 0.13389292359352112, Accuracy: 97.09429931640625
# Epoch 76, Loss: 0.130311980843544, Accuracy: 97.08646392822266
# Epoch 77, Loss: 0.12662845849990845, Accuracy: 97.34492492675781
# Epoch 78, Loss: 0.12240517884492874, Accuracy: 97.32926177978516
# Epoch 79, Loss: 0.11757158488035202, Accuracy: 97.45457458496094
# Epoch 80, Loss: 0.11345303058624268, Accuracy: 97.560302734375
# Epoch 81, Loss: 0.10688627511262894, Accuracy: 97.68953704833984
# Epoch 82, Loss: 0.10348911583423615, Accuracy: 97.86576080322266
# Epoch 83, Loss: 0.09833045303821564, Accuracy: 97.95582580566406
# Epoch 84, Loss: 0.09297256171703339, Accuracy: 98.10072326660156
# Epoch 85, Loss: 0.08913294970989227, Accuracy: 98.13988494873047
# Epoch 86, Loss: 0.08562474697828293, Accuracy: 98.22212219238281
# Epoch 87, Loss: 0.08154460042715073, Accuracy: 98.3474349975586
# Epoch 88, Loss: 0.07748425006866455, Accuracy: 98.38658905029297
# Epoch 89, Loss: 0.07533547282218933, Accuracy: 98.47274780273438
# Epoch 90, Loss: 0.07139278203248978, Accuracy: 98.5432357788086
# Epoch 91, Loss: 0.06836278736591339, Accuracy: 98.58631134033203
# Epoch 92, Loss: 0.0648452490568161, Accuracy: 98.72337341308594
# Epoch 93, Loss: 0.06301765143871307, Accuracy: 98.77427673339844
# Epoch 94, Loss: 0.05990682542324066, Accuracy: 98.84868621826172
# Epoch 95, Loss: 0.05589756742119789, Accuracy: 98.89958953857422
# Epoch 96, Loss: 0.05403514206409454, Accuracy: 99.02490234375
# Epoch 97, Loss: 0.05009728670120239, Accuracy: 99.07972717285156
# Epoch 98, Loss: 0.04822951555252075, Accuracy: 99.09539031982422
# Epoch 99, Loss: 0.04744436591863632, Accuracy: 99.10322570800781
# Epoch 100, Loss: 0.045350950211286545, Accuracy: 99.12672424316406
# Epoch 101, Loss: 0.04321051016449928, Accuracy: 99.20112609863281
# Epoch 102, Loss: 0.042551442980766296, Accuracy: 99.20112609863281
# Epoch 103, Loss: 0.04068116471171379, Accuracy: 99.25987243652344
# Epoch 104, Loss: 0.03875398635864258, Accuracy: 99.29903411865234
# Epoch 105, Loss: 0.03691401332616806, Accuracy: 99.3538589477539
# Epoch 106, Loss: 0.034032516181468964, Accuracy: 99.40084838867188
# Epoch 107, Loss: 0.03201661631464958, Accuracy: 99.4517593383789
# Epoch 108, Loss: 0.030298111960291862, Accuracy: 99.49091339111328
# Epoch 109, Loss: 0.02852758951485157, Accuracy: 99.55357360839844
# Epoch 110, Loss: 0.027399152517318726, Accuracy: 99.54573822021484
# Epoch 111, Loss: 0.026356328278779984, Accuracy: 99.54182434082031
# Epoch 112, Loss: 0.02806643396615982, Accuracy: 99.54182434082031
# Epoch 113, Loss: 0.026746205985546112, Accuracy: 99.58098602294922
# Epoch 114, Loss: 0.023624977096915245, Accuracy: 99.63972473144531
# Epoch 115, Loss: 0.02280433103442192, Accuracy: 99.66322326660156
# Epoch 116, Loss: 0.021758317947387695, Accuracy: 99.69063568115234
# Epoch 117, Loss: 0.0203996729105711, Accuracy: 99.71804809570312
# Epoch 118, Loss: 0.02035355567932129, Accuracy: 99.6984634399414
# Epoch 119, Loss: 0.019524671137332916, Accuracy: 99.69454956054688
# Epoch 120, Loss: 0.01819378137588501, Accuracy: 99.76112365722656
# Epoch 121, Loss: 0.01726294308900833, Accuracy: 99.78070068359375
# Epoch 122, Loss: 0.016796451061964035, Accuracy: 99.7454605102539
# Epoch 123, Loss: 0.015988102182745934, Accuracy: 99.75328826904297
# Epoch 124, Loss: 0.015626735985279083, Accuracy: 99.78070068359375
# Epoch 125, Loss: 0.016772111877799034, Accuracy: 99.76112365722656
# Epoch 126, Loss: 0.017427267506718636, Accuracy: 99.77287292480469
# Epoch 127, Loss: 0.016463981941342354, Accuracy: 99.78853607177734
# Epoch 128, Loss: 0.015052898786962032, Accuracy: 99.80811309814453
# Epoch 129, Loss: 0.014267532154917717, Accuracy: 99.7963638305664
# Epoch 130, Loss: 0.014941487461328506, Accuracy: 99.82377624511719
# Epoch 131, Loss: 0.013246581889688969, Accuracy: 99.83161163330078
# Epoch 132, Loss: 0.012388806790113449, Accuracy: 99.84727478027344
# Epoch 133, Loss: 0.011254061944782734, Accuracy: 99.87077331542969
# Epoch 134, Loss: 0.011109552346169949, Accuracy: 99.85118865966797
# Epoch 135, Loss: 0.01075476873666048, Accuracy: 99.83943939208984
# Epoch 136, Loss: 0.010230736806988716, Accuracy: 99.86685180664062
# Epoch 137, Loss: 0.009687574580311775, Accuracy: 99.88252258300781
# Epoch 138, Loss: 0.009160601533949375, Accuracy: 99.87468719482422
# Epoch 139, Loss: 0.00894177332520485, Accuracy: 99.87860107421875
# Epoch 140, Loss: 0.00871842261403799, Accuracy: 99.90601348876953
# Epoch 141, Loss: 0.00823117420077324, Accuracy: 99.8942642211914
# Epoch 142, Loss: 0.007956938818097115, Accuracy: 99.89035034179688
# Epoch 143, Loss: 0.007720663212239742, Accuracy: 99.90601348876953
# Epoch 144, Loss: 0.007677367888391018, Accuracy: 99.88643646240234
# Epoch 145, Loss: 0.007534184027463198, Accuracy: 99.89818572998047
# Epoch 146, Loss: 0.007238632999360561, Accuracy: 99.90601348876953
# Epoch 147, Loss: 0.006896414328366518, Accuracy: 99.89818572998047
# Epoch 148, Loss: 0.006730941124260426, Accuracy: 99.89035034179688
# Epoch 149, Loss: 0.0065546524710953236, Accuracy: 99.91384887695312
# Epoch 150, Loss: 0.006304273381829262, Accuracy: 99.8942642211914
# Epoch 151, Loss: 0.006202307064086199, Accuracy: 99.9099349975586
# Epoch 152, Loss: 0.006237026769667864, Accuracy: 99.902099609375
# Epoch 153, Loss: 0.006011053919792175, Accuracy: 99.91776275634766
# Epoch 154, Loss: 0.006115096155554056, Accuracy: 99.9099349975586
# Epoch 155, Loss: 0.006061443127691746, Accuracy: 99.91776275634766
# Epoch 156, Loss: 0.006263211369514465, Accuracy: 99.902099609375
# Epoch 157, Loss: 0.0056600421667099, Accuracy: 99.91384887695312
# Epoch 158, Loss: 0.005358807742595673, Accuracy: 99.91384887695312
# Epoch 159, Loss: 0.005291407462209463, Accuracy: 99.91384887695312
# Epoch 160, Loss: 0.005157256964594126, Accuracy: 99.90601348876953
# Epoch 161, Loss: 0.00517507828772068, Accuracy: 99.90601348876953
# Epoch 162, Loss: 0.00503987492993474, Accuracy: 99.92559814453125
# Epoch 163, Loss: 0.004859431646764278, Accuracy: 99.9099349975586
# Epoch 164, Loss: 0.004765124060213566, Accuracy: 99.9099349975586
# Epoch 165, Loss: 0.004527580458670855, Accuracy: 99.91384887695312
# Epoch 166, Loss: 0.004847894888371229, Accuracy: 99.9099349975586
# Epoch 167, Loss: 0.004667605273425579, Accuracy: 99.9099349975586
# Epoch 168, Loss: 0.0046893395483493805, Accuracy: 99.90601348876953
# Epoch 169, Loss: 0.004558249842375517, Accuracy: 99.90601348876953
# Epoch 170, Loss: 0.004468039609491825, Accuracy: 99.91384887695312
# Epoch 171, Loss: 0.004247606266289949, Accuracy: 99.92559814453125
# Epoch 172, Loss: 0.004832400940358639, Accuracy: 99.89035034179688
# Epoch 173, Loss: 0.008390096947550774, Accuracy: 99.82769775390625
# Epoch 174, Loss: 0.009806741960346699, Accuracy: 99.81986236572266
# Epoch 175, Loss: 0.008464407175779343, Accuracy: 99.85902404785156
# Epoch 176, Loss: 0.008077079430222511, Accuracy: 99.87860107421875
# Epoch 177, Loss: 0.006500415038317442, Accuracy: 99.89035034179688
# Epoch 178, Loss: 0.006566941272467375, Accuracy: 99.87860107421875
# Epoch 179, Loss: 0.006422457750886679, Accuracy: 99.88252258300781
# Epoch 180, Loss: 0.005775481462478638, Accuracy: 99.9099349975586
# Epoch 181, Loss: 0.004812596365809441, Accuracy: 99.9099349975586
# Epoch 182, Loss: 0.004279847722500563, Accuracy: 99.902099609375
# Epoch 183, Loss: 0.003831855719909072, Accuracy: 99.92167663574219
# Epoch 184, Loss: 0.003796021221205592, Accuracy: 99.92559814453125
# Epoch 185, Loss: 0.0037565655075013638, Accuracy: 99.92167663574219
# Epoch 186, Loss: 0.003687793854624033, Accuracy: 99.9099349975586
# Epoch 187, Loss: 0.003555723698809743, Accuracy: 99.91384887695312
# Epoch 188, Loss: 0.0037196502089500427, Accuracy: 99.90601348876953
# Epoch 189, Loss: 0.0036000965628772974, Accuracy: 99.91384887695312
# Epoch 190, Loss: 0.0035656068939715624, Accuracy: 99.91776275634766
# Epoch 191, Loss: 0.0034655143972486258, Accuracy: 99.91776275634766
# Epoch 192, Loss: 0.003451224882155657, Accuracy: 99.91384887695312
# Epoch 193, Loss: 0.00317292264662683, Accuracy: 99.91384887695312
# Epoch 194, Loss: 0.0031672168988734484, Accuracy: 99.91384887695312
# Epoch 195, Loss: 0.0033308849669992924, Accuracy: 99.902099609375
# Epoch 196, Loss: 0.002954954979941249, Accuracy: 99.92559814453125
# Epoch 197, Loss: 0.0031826714985072613, Accuracy: 99.92167663574219
# Epoch 198, Loss: 0.003052608110010624, Accuracy: 99.93342590332031
# Epoch 199, Loss: 0.0029688908252865076, Accuracy: 99.91384887695312
# Epoch 200, Loss: 0.0030190409161150455, Accuracy: 99.91384887695312

# %% [markdown]
# ## 테스트 루프

# %%
for test_seq, test_labels in test_ds:
    prediction = test_step(model, test_seq)
    test_text = tokenizer.sequences_to_texts(test_seq.numpy())
    gt_text = tokenizer.sequences_to_texts(test_labels.numpy())
    texts = tokenizer.sequences_to_texts(prediction.numpy())
    print('_')
    print('q: ', test_text)
    print('a: ', gt_text)
    print('p: ', texts)
# Out:
# _
# q:  ['여기 기프티콘 되죠 \n']
# a:  ['\t 네 현금영수증 해드릴까 요 \n']
# p:  ['네 앞 에 담아 드리겠습니다 \n']
# _
# q:  ['네 에 테이크 아웃 도 가능한가요 \n']
# a:  ['\t 네 로 오시 면 테이크 아웃 잔 에 담아 드려요 \n']
# p:  ['네 당연히 디카 페인 500원 추가 됩니다 \n']
# _
# q:  ['아메리카노 톨 사이즈 로 주세요 \n']
# a:  ['\t 따뜻한 거 로 드릴 까요 \n']
# p:  ['사이즈 는 어떻게 드릴 까요 \n']
# _
# q:  ['진동 을 따로 주시나요 \n']
# a:  ['\t 주 번호 로 드리겠습니다 \n']
# p:  ['네 카드 도 와 은 방법 수 는 어떤 걸 로 드릴 수 있습니다 \n']
# _
# q:  ['자리 있나요 \n']
# a:  ['\t 네 있습니다 \n']
# p:  ['네 자리 있습니다']
# _
# q:  ['그럼 루이보스 밀크 티 하나 \n']
# a:  ['\t 네 알겠습니다 \n']
# p:  ['네 4500원 입니다 \n']
# _
# q:  ['다음 에 무료 로 하고 엔 도장 찍어주세요 \n']
# a:  ['\t 네 \n']
# p:  ['네 앞 에 휘핑 케이크 로 드리겠습니다 \n']
# _
# q:  ['아메리카노 한 잔 에 얼마 죠 \n']
# a:  ['\t 입니다 \n']
# p:  ['4000원 입니다 \n']
# _
# q:  ['얼마나 \n']
# a:  ['\t 바로 만들어 드릴게요 \n']
# p:  ['대략 5분 정도 걸립니다 \n']
# _
# q:  ['카푸치노 는 로 주시 고 아메리카노 는 로 \n']
# a:  ['\t 네 더 없으세요 \n']
# p:  ['네 번호 해드리겠습니다 \n']
# _
# q:  ['아메리카노 는 어떤 종류 가 있나요 \n']
# a:  ['\t 디카 페인 과 기본 아메리카노 2 종류 있습니다 \n']
# p:  ['네 캐리어 에 이드 사이즈 업 가능해요 \n']
# _
# q:  ['카카오 페이 로 결제 가능한가요 \n']
# a:  ['\t 네 가능합니다 \n']
# p:  ['그럼요 \n']
# _
# q:  ['오늘 의 커피 는 커피 로 하나요 맛 이 \n']
# a:  ['\t 아 네 오늘 은 과테말라 커피 입니다 \n']
# p:  ['아메리카노 생크림 는 아메리카노 인 나가요 \n']
# _
# q:  ['머핀 은 뭐 가 제일 \n']
# a:  ['\t 블루베리 머핀 이 잘 나갑니다 \n']
# p:  ['초코 칩 쿠키 입니다 \n']
# _
# q:  ['현금 영수증 해주세요 \n']
# a:  ['\t 네 번호 찍어주세요 \n']
# p:  ['네 번호 찍어주세요 \n']
# _
# q:  ['둘 다 톨 사이즈 로 주세요 \n']
# a:  ['\t 여기 서 드시고 요 \n']
# p:  ['할인 카드 있으신 가요 \n']
# _
# q:  ['아이스 아메리카노 한 잔 가능한가요 \n']
# a:  ['\t 네 가능합니다 \n']
# p:  ['가능합니다만 가격 이 천 원 더 올라가게 됩니다 \n']
# _
# q:  ['아이스 아메리카노 에 샷 이 몇 개 \n']
# a:  ['\t 아이스 아메리카노 에 샷 은 개 \n']
# p:  ['아메리카노 아메리카노 아메리카노 적립 사용 되었습니다 \n']
# _
# q:  ['카페라테 한 잔 주세요 \n']
# a:  ['\t 카페라테 따뜻한 걸 로 드릴 까요 \n']
# p:  ['네 카페라떼 컵 사이즈 는 뭘 로 드릴 까요 \n']
# _
# q:  ['아니요 \n']
# a:  ['\t 네 더 필요하신 건 없으신 가요 \n']
# p:  ['따뜻한 것 으로 드릴가요 \n']
# _
# q:  ['네 찍어주세요 \n']
# a:  ['\t 네 주문 딸기 스무디 와 쿠키 드릴게요 \n']
# p:  ['진동 벨 로 알려 드릴게요 \n']
# _
# q:  ['시즌 메뉴 오늘 도 가능한가요 \n']
# a:  ['\t 네 시즌 메뉴 가능합니다 \n']
# p:  ['네 치즈케이크 는 따뜻하게만 입니다 \n']
# _
# q:  ['시즌 메뉴 와 함께 되어 있는 세트 메뉴 가 있나요 \n']
# a:  ['\t 네 치즈 케이크 와 시즌 메뉴 두 잔 으로 세트 메뉴 있습니다 \n']
# p:  ['피지 와 이 안되고 루이보스 가 가능해요 \n']
# _
# q:  ['라테 에 우유 두 도 변경 가능한가요 \n']
# a:  ['\t 네 라테 에 두유 로 변경 가능합니다 \n']
# p:  ['가능합니다만 개 이 천 원 더 됩니다 \n']
# _
# q:  ['네 먹고 갈 거 예요 \n']
# a:  ['\t 카드 여기 주세요 \n']
# p:  ['가실 거 로 드릴 까요 \n']
# _
# q:  ['카페인 이 음료 있나요 \n']
# a:  ['\t 티 음료 와 스무디 에는 카페인 이 않습니다 \n']
# p:  ['피지 와 은 루이보스 있습니다 \n']
# _
# q:  ['딸기스무디 랑 키위 스무디 는 생 과일 인가요 \n']
# a:  ['\t 딸기 는 키위 는 생 과일 을 사용 하고 있습니다 \n']
# p:  ['그럼요 \n']
# _
# q:  ['그럼 딸기 스무디 하나 주세요 \n']
# a:  ['\t 드시고 가시나요 \n']
# p:  ['스콘 은 데워 드릴 까요 \n']
# _
# q:  ['아메리카노 한 잔이요 \n']
# a:  ['\t 아이스 아메리카노 로 드릴 까요 \n']
# p:  ['아이스 프라푸치노 사이즈 는 뭘 로 드릴 까요 \n']
# _
# q:  ['네 도 같이 \n']
# a:  ['\t 네 아메리카노 4000원 입니다 \n']
# p:  ['아이스 프라푸치노 사이즈 는 뭘 로 드릴 까요 \n']
# _
# q:  ['디카 페인 아이스 아메리카노 한 잔 주세요 \n']
# a:  ['\t 디카 페인 아이스 아메리카노 는 기존 금액 에 300원 추가 되는데 괜찮으신 가요 \n']
# p:  ['네 카페라떼 컵 사이즈 는 뭘 로 드릴 까요 \n']
# _
# q:  ['커피 음료 것 뭐 가 있나요 \n']
# a:  ['\t 스무디 와 주스 있습니다 \n']
# p:  ['요즘 은 초코 케이크 가 제일 잘나가요 \n']
# _
# q:  ['주스 어떤 종류 있나요 \n']
# a:  ['\t 딸기 주스 주스 주스 가 있습니다 \n']
# p:  ['네 기다리시면 안내 해드릴게요 \n']
# _
# q:  ['플랫 화이트 라지 로 주세요 \n']
# a:  ['\t 네 \n']
# p:  ['초코 머핀 데워 드릴 까요 \n']
# _
# q:  ['네 레드 벨벳 케이크 주세요 \n']
# a:  ['\t 음료 는 뭘 로 드릴 까요 \n']
# p:  ['레귤러 두 안 필요하신가요 \n']
# _
# q:  ['네 먹고 갈 거 예요 \n']
# a:  ['\t 유리잔 괜찮으세요 \n']
# p:  ['가실 거 로 드릴 까요 \n']
# _
# q:  ['따뜻한 밀크 티 주세요 \n']
# a:  ['\t 네 \n']
# p:  ['카페모카 5천 원 입니다 \n']
# _
# q:  ['음료 얼마나 하나요 \n']
# a:  ['\t 10분 정도 주시 면 됩니다 \n']
# p:  ['10분 내 가 나갑니다 \n']
# _
# q:  ['아이스 아메리카노 한잔 얼마 인가요 \n']
# a:  ['\t 4500원 입니다 \n']
# p:  ['아이스 아메리카노 1 잔 은 4000원 아이스 카페라테 1 잔 은 5000원 입니다 \n']
# _
# q:  ['현금영수증 번호 \n']
# a:  ['\t 네 \n']
# p:  ['네 번호 입력 해주세요 \n']
# _
# q:  ['이 카드 로 결제 해주세요 \n']
# a:  ['\t 네 결제 도 와 드릴게요 \n']
# p:  ['네 결제 해드렸습니다 \n']
# _
# q:  ['주문 한 게 다 안 \n']
# a:  ['\t 주 번호 가 몇 이 죠 \n']
# p:  ['네 4500원 입니다 \n']
# _
# q:  ['을 \n']
# a:  ['\t \n']
# p:  ['500 원 추가 입니다 \n']
# _
# q:  ['베이글 은 얼마 인가요 \n']
# a:  ['\t 베이글 은 2000원 입니다 \n']
# p:  ['500원 추가 하면 입니다 \n']
# _
# q:  ['지금 되나요 \n']
# a:  ['\t 는 계절 메뉴 라 지금 은 판매 하지 않습니다 \n']
# p:  ['네 네 가능합니다 \n']
# _
# q:  ['바닐라 라테 는 따뜻하게 주세요 \n']
# a:  ['\t 네 적립 이나 할인 카드 있으세요 \n']
# p:  ['네 진동 벨 울리면 픽업 대로 와주세요 \n']
# _
# q:  ['테이크 아웃 으로 부탁드립니다 \n']
# a:  ['\t 결제 는 이 쪽 에서 도 와 드릴게요 \n']
# p:  ['네 1500원 더 만 기다려주세요 \n']
# _
# q:  ['혹시 테이크 아웃 잔 에 수 있나요 \n']
# a:  ['\t 테이크 아웃 하시는 건가 요 \n']
# p:  ['네 네 있습니다']
# _
# q:  ['아메리카노 하나 는 샷 추가 해주세요 \n']
# a:  ['\t 아메리카노 는 둘 다 따뜻한 걸 로 드릴 까요 \n']
# p:  ['네 앞 에 가능하세요 \n']
# _
# q:  ['쿠폰 찍어주세요 \n']
# a:  ['\t 네 찍어 드릴게요 \n']
# p:  ['10 개 다모아 오시 면 커피한잔 드려요 \n']
# _
# q:  ['주문 할게요 \n']
# a:  ['\t 어떤 거 드릴 까요 \n']
# p:  ['네 어떤 걸 로 하시겠습니까 \n']
# _
# q:  ['파나요 \n']
# a:  ['\t 는 계절 지금 은 \n']
# p:  ['네 손님 메뉴 는 어떻게 드릴 까요 \n']
# _
# q:  ['그럼 겨울 메뉴 뭐 가 \n']
# a:  ['\t 겨울 엔 감귤 라테 가 제일 많이 나가요 \n']
# p:  ['네 초코 케이크 는 판매 하지 않습니다 \n']
# _
# q:  ['네 결제 는 카드 로 할게요 \n']
# a:  ['\t 네 결제 완료 되었습니다 \n']
# p:  ['네 그렇게 해드리겠습니다 \n']
# _
# q:  ['둘 다 사이즈 로 할게요 \n']
# a:  ['\t 네 결제 는 어떤 것 으로 도 와 드릴 까요 \n']
# p:  ['네 카드 카드 주시 면 도 와 드리겠습니다 \n']
# _
# q:  ['기프티콘 으로 결제 할게요 \n']
# a:  ['\t 네 그럼 쿠폰 저 \n']
# p:  ['저 한테 보여주시고 제 가 확인 버튼 누르면 돼요 \n']
# _
# q:  ['녹차 라테 1 잔 주세요 \n']
# a:  ['\t 따뜻한 걸 로 드릴 까요 \n']
# p:  ['휘핑크림 올려 드릴 까요 \n']
# _
# q:  ['네 그럼 휘핑크림 추가 해서 주세요 \n']
# a:  ['\t 네 녹차 라테 에 휘핑크림 추가 해서 4500원 입니다 \n']
# p:  ['네 결제 도 와 드릴게요 \n']
# _
# q:  ['브레드 종류 는 뭐 가 있나요 \n']
# a:  ['\t 허니 브레드 와 갈릭 치즈 브레드 가 있습니다 \n']
# p:  ['피지 와 안되고 루이보스 는 500원 추가 됩니다 \n']
# _
# q:  ['생크림 이 건 어떤 건가 요 \n']
# a:  ['\t 허니 브레드 입니다 \n']
# p:  ['네 앞 만 기다려주세요 \n']
# _
# q:  ['네 그렇게 만들어 주세요 \n']
# a:  ['\t 더 필요한 건 없으세요 \n']
# p:  ['네 진동 벨 울리면 찾으러 오세요 \n']
# _
# q:  ['여기 있습니다 \n']
# a:  ['\t 네 확인 되셨고 되면 진동 벨 거 예요 \n']
# p:  ['여기 진동 벨 가지 고 계시다가 울리면 주문 한 음료 가져가세요 \n']
# _
# q:  ['핫초코 한 잔 아메리카노 사이 즈 업 한 잔 하면 얼마 인가요 \n']
# a:  ['\t 입니다 \n']
# p:  ['9500원 입니다 \n']
# _
# q:  ['주스 는 다른 건 없나요 \n']
# a:  ['\t 그럼 에 라테 추천 \n']
# p:  ['네 4500원 입니다 \n']
# _
# q:  ['그건 \n']
# a:  ['\t 네 만 따듯 해 요 \n']
# p:  ['오늘 은 다 팔렸어요 \n']
# _
# q:  ['통신사 할인 되죠 \n']
# a:  ['\t 네 300원 할인 됩니다 \n']
# p:  ['네 멤버십 앞 만 해드릴게요 \n']
# _
# q:  ['매장 에서 언제 까지 영업 하시나요 \n']
# a:  ['\t 오후 10시 까지 영업 입니다 \n']
# p:  ['네 유효 쪽 에 있습니다 \n']
# _
# q:  ['아니요 그냥 주세요 \n']
# a:  ['\t 결제 해드릴게요 \n']
# p:  ['카페모카 5천 원 입니다 \n']
# _
# q:  ['가격 안 되나요 \n']
# a:  ['\t 한 해드릴게요 \n']
# p:  ['네 있습니다 \n']
# _
# q:  ['카페라테 한잔 주세요 \n']
# a:  ['\t 따뜻한 걸 로 드릴 까요 \n']
# p:  ['네 드시고 가시나요 \n']
# _
# q:  ['네 차가운 걸 로 주세요 \n']
# a:  ['\t 4500원 입니다 \n']
# p:  ['네 카페라떼 아메리카노 사이즈 는 뭘 로 드릴 까요 \n']
# _
# q:  ['어떤 게 괜찮아요 \n']
# a:  ['\t 이나 원두 를 하시는 게 아니면 예 가체 많이 추천 \n']
# p:  ['라임 하고 자몽 이 있습니다 \n']
# _
# q:  ['그럼 추천 치즈 케이크 도 같이 주세요 \n']
# a:  ['\t 네 매장 에서 드시고 가시나요 \n']
# p:  ['네 저희 적립 카드 한 적립 주시 면 있습니다 \n']
# _
# q:  ['그리고 휘핑크림 은 에스프레소 크림 으로 \n']
# a:  ['\t 결제 는 어떻게 해드릴까 요 \n']
# p:  ['네 포인트 적립 카드 있으세요 \n']
# _
# q:  ['지금 도 할인 하나요 \n']
# a:  ['\t 네 10시 까지 하고 있습니다 \n']
# p:  ['네 진동 벨 울리면 와주세요 \n']
# _
# q:  ['그럼 와 아이스 아메리카노 로 할게요 \n']
# a:  ['\t 더 필요하신 건 없나요 \n']
# p:  ['네 총 18000원 입니다 \n']
# _
# q:  ['네 할인 적립 은 \n']
# a:  ['\t 네 바코드 \n']
# p:  ['아이스 로 드릴 까요 \n']
# _
# q:  ['초코 프라푸치노 주세요 \n']
# a:  ['\t 휘핑 올려 드릴 까요 \n']
# p:  ['네 아이스 프라푸치노 몇 잔 드릴 까요 \n']
# _
# q:  ['시럽 도 가 \n']
# a:  ['\t 드시고 가시나요 \n']
# p:  ['아이스 프라푸치노 사이즈 는 뭘 로 드릴 까요 \n']
# _
# q:  ['둘 다 사이즈 로 주세요 \n']
# a:  ['\t 드시고 가시나요 \n']
# p:  ['할인 카드 있으신 가요 \n']
# _
# q:  ['마시다가 갈 건데 테이크아웃 으로 주세요 \n']
# a:  ['\t 상 매장 에서는 머그컵 으로 드리고 있어요 \n']
# p:  ['따뜻한 것 과 1천 원']
# _
# q:  ['나갈 때 테이크아웃 컵 으로 수 있나요 \n']
# a:  ['\t 네 그렇게 해드릴게요 \n']
# p:  ['네 영수증 드릴게요 \n']
# _
# q:  ['아메리카노 두 잔 한잔 주세요 \n']
# a:  ['\t 드시고 가실 건가 요 \n']
# p:  ['따뜻한 거 로 드릴 까요 \n']
# _
# q:  ['얼마나 하나요 \n']
# a:  ['\t 5분 정도 \n']
# p:  ['10분 정도 걸려요 \n']
# _
# q:  ['포인트 적립 해주세요 \n']
# a:  ['\t 네 번호 입력 부탁드립니다 \n']
# p:  ['여기 나오면 사이즈 는 뭘 로 하시겠어요 \n']
# _
# q:  ['네 번호 로 할게요 \n']
# a:  ['\t 네 에 번호 \n']
# p:  ['주차 는 하셨나요 \n']
# _
# q:  ['아 포인트 포인트 사용 해주세요 \n']
# a:  ['\t 네 고객 님 포인트 총 있으신 데 사용 도 와 드리겠습니다 \n']
# p:  ['네 있습니다 \n']
# _
# q:  ['톨 사이즈 로 주문 할게요 \n']
# a:  ['\t 네 계산 도 와 드리겠습니다 \n']
# p:  ['네 총 18000원 입니다 \n']
# _
# q:  ['아메리카노 사이즈 가능한가요 \n']
# a:  ['\t 네 500원 만 추가 하시면 가능하십니다 \n']
# p:  ['가능합니다만 가격 은 따뜻하게만 입니다 \n']
# _
# q:  ['사이 즈 업 해서 주세요 \n']
# a:  ['\t 네 결제 는 어떻게 도 와 드릴 까요 \n']
# p:  ['네 사이즈 는 어떤 걸 로 주문 넣어 드릴 까요 \n']
# _
# q:  ['커피 는 텀블러 에 담아주세요 \n']
# a:  ['\t 네 텀블러 할인 4000원 결제 도 와 드리겠습니다 \n']
# p:  ['텀블러 할인 300원 같이 해드릴게요 \n']
# _
# q:  ['아니요 아이스 로 주세요 \n']
# a:  ['\t 드시고 가실 건가 요 \n']
# p:  ['레귤러 사이즈 로 괜찮으세요 \n']
# _
# q:  ['테이크아웃 할게요 \n']
# a:  ['\t 지금 중 인데 케이크 주문 하시면 아메리카노 한잔 로 드려요 \n']
# p:  ['네 드릴게요 잠시 만 요 \n']
# _
# q:  ['현금 결제 가 안 \n']
# a:  ['\t 현금 은 에서 주문 도 와 드리겠습니다 \n']
# p:  ['네 이 쪽 에 기계 에 있습니다 \n']
# _
# q:  ['포인트 적립 되나요 \n']
# a:  ['\t 번호 포인트 적립 도 와 드리고 있어요 \n']
# p:  ['네 가능합니다 \n']
# _
# q:  ['포인트 적립 할게요 \n']
# a:  ['\t 네 결제 되셨습니다 \n']
# p:  ['네 카드 받았습니다 \n']
# _
# q:  ['티라미수 는 있나요 \n']
# a:  ['\t 네 티라미수 는 있습니다 \n']
# p:  ['아니요 있습니다 \n']
# _
# q:  ['네 현금영수증 해주세요 \n']
# a:  ['\t 네 드시고 가시나요 \n']
# p:  ['네 번호 적어주세요 \n']
# _
# q:  ['샷 추가 해주세요 \n']
# a:  ['\t 네 알겠습니다 \n']
# p:  ['네 알겠습니다 \n']
# _
# q:  ['얼마 에요 \n']
# a:  ['\t 만 원 입니다 \n']
# p:  ['베이글 과 동일하게 2000원 입니다 \n']
# _
# q:  ['아이스 아메리카노 랑 샌드위치 주세요 \n']
# a:  ['\t 10시 에 세트 할인 가능하세요 \n']
# p:  ['4천원 입니다 \n']

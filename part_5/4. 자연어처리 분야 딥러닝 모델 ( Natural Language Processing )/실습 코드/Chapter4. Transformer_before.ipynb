# %% [markdown]
# # Transformer (Translation)

# %%
import random
import numpy as np
import tensorflow as tf
from konlpy.tag import Okt

from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Lambda, Layer, Embedding, LayerNormalization

# %%
# %pwd
# Out:
# 'C:\\ai_workspace\\part_5\\4. 자연어처리 분야 딥러닝 모델 ( Natural Language Processing )\\실습 코드'

# %%
import os
os.chdir('C:\ai_workspace\part_5\4. 자연어처리 분야 딥러닝 모델 ( Natural Language Processing )\\실습 코드')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-102-2ac9ea0e9655> in <module>
#       1 import os
# ----> 2 os.chdir('C:\ai_workspace\part_5\4. 자연어처리 분야 딥러닝 모델 ( Natural Language Processing )\\실습 코드')
#
# OSError: [WinError 123] 파일 이름, 디렉터리 이름 또는 볼륨 레이블 구문이 잘못되었습니다: 'C:\x07i_workspace\\part_5\x04. 자연어처리 분야 딥러닝 모델 ( Natural Language Processing )\\실습 코드'

# %%
EPOCHS = 200
NUM_WORDS = 2000

# %% [markdown]
# ## Dot-Scaled Attention

# %%
class DotScaledAttention(Layer):
    def __init__(self, d_emb, d_reduced, masked=False):
        super().__init__()
        self.q = Dense(d_reduced, input_shape=(-1, d_emb))
        self.k = Dense(d_reduced, input_shape=(-1, d_emb))
        self.v = Dense(d_reduced, input_shape=(-1, d_emb))
        self.scale = Lambda(lambda x: x/np.sqrt(d_reduced))
        self.masked = masked

    def call(self, x, training=None, mask=None): # (q,k,v)
        q = self.scale(self.q(x[0]))
        k = self.k(x[1])
        v = self.v(x[2])
        
        k_T = tf.transpose(k, perm=[0, 2, 1])
        comp = tf.matmul(q, k_T)
        
        if self.masked: # Referred from https://github.com/LastRemote/Transformer-TF2.0
            length = tf.shape(comp)[-1]
            mask = tf.fill((length, length), -np.inf)
            mask = tf.linalg.band_part(mask, 0, -1) # Get upper triangle
            mask = tf.linalg.set_diag(mask, tf.zeros((length))) # Set diagonal to zeros to avoid operations with infinity
            comp += mask
        comp = tf.nn.softmax(comp, axis=-1)
        return tf.matmul(comp, v)

# %% [markdown]
# ## Multi-Head Attention

# %%
class MultiHeadAttention(Layer):
    def __init__(self, num_head, d_emb, d_reduced, masked=False):
        super().__init__()
        self.attention_list = list()
        for _ in range(num_head):
            self.attention_list.append(DotScaledAttention(d_emb, d_reduced, masked))
        self.linear = Dense(d_emb, input_shape=(-1, num_head * d_reduced))

    def call(self, x, training=None, mask=None):
        attention_list = [a(x) for a in self.attention_list]
        concat = tf.concat(attention_list, axis=-1)
        return self.linear(concat)

# %% [markdown]
# ## Encoder

# %%
class Encoder(Layer):
    def __init__(self, num_head, d_reduced):
        super().__init__()
        self.num_head = num_head
        self.d_r = d_reduced
    
    def build(self, input_shape):
        self.multi_attention = MultiHeadAttention(self.num_head, input_shape[-1], self.d_r)
        self.layer_norm1 = LayerNormalization(input_shape=input_shape)
        self.dense1 = Dense(input_shape[-1] * 4, input_shape=input_shape, activation='relu')
        self.dense2 = Dense(input_shape[-1],
                            input_shape=self.dense1.compute_output_shape(input_shape))
        self.layer_norm2 = LayerNormalization(input_shape=input_shape)
        super().build(input_shape)

    def call(self, x, training=None, mask=None):
        h = self.multi_attention((x, x, x))
        ln1 = self.layer_norm1(x + h)
        
        h = self.dense2(self.dense1(ln1))
        return self.layer_norm2(h + ln1)

    def compute_output_shape(self, input_shape):
        return input_shape

# %% [markdown]
# ## Decoder

# %%
class Decoder(Layer):
    def __init__(self, num_head, d_reduced):
        super().__init__()
        self.num_head = num_head
        self.d_r = d_reduced
    
    def build(self, input_shape):
        self.self_attention = MultiHeadAttention(self.num_head, input_shape[0][-1], self.d_r, masked=True)
        self.layer_norm1 = LayerNormalization(input_shape=input_shape)
        
        self.multi_attention = MultiHeadAttention(self.num_head, input_shape[0][-1], self.d_r)
        self.layer_norm2 = LayerNormalization(input_shape=input_shape)
        
        self.dense1 = Dense(input_shape[0][-1] * 4, input_shape=input_shape[0], activation='relu')
        self.dense2 = Dense(input_shape[0][-1],
                            input_shape=self.dense1.compute_output_shape(input_shape[0]))
        self.layer_norm3 = LayerNormalization(input_shape=input_shape)
        super().build(input_shape)

    def call(self, inputs, training=None, mask=None): # (x, context)
        x, context = inputs
        h = self.self_attention((x, x, x))
        ln1 = self.layer_norm1(x + h)
        
        h = self.multi_attention((ln1, context, context))
        ln2 = self.layer_norm2(ln1 + h)
        
        h = self.dense2(self.dense1(ln2))
        return self.layer_norm3(h + ln2)

    def compute_output_shape(self, input_shape):
        return input_shape

# %% [markdown]
# ## Positional Encoding

# %%
class PositionalEncoding(Layer):  # Referred from https://github.com/LastRemote/Transformer-TF2.0
    def __init__(self, max_len, d_emb):
        super().__init__()
        self.sinusoidal_encoding = np.array([self.get_positional_angle(pos, d_emb) for pos in range(max_len)], dtype=np.float32)
        self.sinusoidal_encoding[:, 0::2] = np.sin(self.sinusoidal_encoding[:, 0::2])
        self.sinusoidal_encoding[:, 1::2] = np.cos(self.sinusoidal_encoding[:, 1::2])
        self.sinusoidal_encoding = tf.cast(self.sinusoidal_encoding, dtype=tf.float32)

    def call(self, x, training=None, mask=None):
        return x + self.sinusoidal_encoding[:tf.shape(x)[1]]

    def compute_output_shape(self, input_shape):
        return input_shape

    def get_angle(self, pos, dim, d_emb):
        return pos / np.power(10000, 2 * (dim // 2) / d_emb)

    def get_positional_angle(self, pos, d_emb):
        return [self.get_angle(pos, dim, d_emb) for dim in range(d_emb)]

# %% [markdown]
# ## Transformer Architecture

# %%
class Transformer(Model):
    def __init__(self, src_vocab, dst_vocab, max_len, d_emb,
                       d_reduced, n_enc_layer, n_dec_layer, num_head):
        super().__init__()
        self.enc_emb = Embedding(src_vocab, d_emb)
        self.dec_emb = Embedding(dst_vocab, d_emb)
        self.pos_enc = PositionalEncoding(max_len, d_emb)
        
        self.encoder = [Encoder(num_head, d_reduced) for _ in range(n_enc_layer)]
        self.decoder = [Decoder(num_head, d_reduced) for _ in range(n_dec_layer)]
        self.dense = Dense(dst_vocab, input_shape=(-1, d_emb))

    def call(self, inputs, training=None, mask=None): # (src_sentence, dst_sentence_shifted)
        src_sent, dst_sent_shifted = inputs
        
        h_enc = self.pos_enc(self.enc_emb(src_sent))
        for enc in self.encoder:
            h_enc = enc(h_enc)
            
        h_dec = self.pos_enc(self.dec_emb(dst_sent_shifted))
        for dec in self.decoder:
            h_dec = dec([h_dec, h_enc])
            
        return tf.nn.softmax(self.dense(h_dec), axis=-1)

# %% [markdown]
# ## Dataset 준비

# %%
dataset_file = '../data/chatbot_data.csv' # acquired from 'http://www.aihub.or.kr' and modified
okt = Okt()

with open(dataset_file, 'r') as file:
    lines = file.readlines()
    seq = [' '.join(okt.morphs(line)) for line in lines]

questions = seq[::2]
answers = ['\t ' + lines for lines in seq[1::2]]

num_sample = len(questions)

perm = list(range(num_sample))
random.seed(0)
random.shuffle(perm)

train_q = list()
train_a = list()
test_q = list()
test_a = list()

for idx, qna in enumerate(zip(questions, answers)):
    q, a = qna
    if perm[idx] > num_sample//5:
        train_q.append(q)
        train_a.append(a)
    else:
        test_q.append(q)
        test_a.append(a)

tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=NUM_WORDS,
                                                  filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~')

tokenizer.fit_on_texts(train_q + train_a)

train_q_seq = tokenizer.texts_to_sequences(train_q)
train_a_seq = tokenizer.texts_to_sequences(train_a)

test_q_seq = tokenizer.texts_to_sequences(test_q)
test_a_seq = tokenizer.texts_to_sequences(test_a)

x_train = tf.keras.preprocessing.sequence.pad_sequences(train_q_seq,
                                                        value=0,
                                                        padding='pre',
                                                        maxlen=64)
y_train = tf.keras.preprocessing.sequence.pad_sequences(train_a_seq,
                                                        value=0,
                                                        padding='post',
                                                        maxlen=65)
y_train_shifted = np.concatenate([np.zeros((y_train.shape[0], 1)), y_train[:, 1:]], axis=1)


x_test = tf.keras.preprocessing.sequence.pad_sequences(test_q_seq,
                                                       value=0,
                                                       padding='pre',
                                                       maxlen=64)
y_test = tf.keras.preprocessing.sequence.pad_sequences(test_a_seq,
                                                       value=0,
                                                       padding='post',
                                                       maxlen=65)

# %% [markdown]
# ## Train using keras

# %%
transformer = Transformer(NUM_WORDS,
                          NUM_WORDS,
                          128, 16, 16, 2, 2, 4) # Instantiating a new transformer model

transformer.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
transformer.fit([x_train, y_train_shifted], y_train, batch_size=5, epochs=EPOCHS)
# Out:
# Epoch 1/200
# 80/80 [==============================] - 22s 70ms/step - loss: 6.0357 - accuracy: 0.8344
# Epoch 2/200
# 80/80 [==============================] - 5s 59ms/step - loss: 2.8009 - accuracy: 0.8900
# Epoch 3/200
# 80/80 [==============================] - 5s 61ms/step - loss: 1.0247 - accuracy: 0.8900
# Epoch 4/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.7284 - accuracy: 0.8900
# Epoch 5/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.6200 - accuracy: 0.8969
# Epoch 6/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.5511 - accuracy: 0.9192
# Epoch 7/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.5004 - accuracy: 0.9215
# Epoch 8/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.4678 - accuracy: 0.9258
# Epoch 9/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.4420 - accuracy: 0.9265
# Epoch 10/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.4164 - accuracy: 0.9285
# Epoch 11/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3920 - accuracy: 0.9328
# Epoch 12/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3702 - accuracy: 0.9348
# Epoch 13/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.3471 - accuracy: 0.9364
# Epoch 14/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.3258 - accuracy: 0.9404
# Epoch 15/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.3039 - accuracy: 0.9463
# Epoch 16/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2845 - accuracy: 0.9501
# Epoch 17/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2677 - accuracy: 0.9526
# Epoch 18/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2503 - accuracy: 0.9564
# Epoch 19/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2351 - accuracy: 0.9594
# Epoch 20/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.2199 - accuracy: 0.9629
# Epoch 21/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2069 - accuracy: 0.9650
# Epoch 22/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.1936 - accuracy: 0.9673
# Epoch 23/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.1818 - accuracy: 0.9699
# Epoch 24/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1704 - accuracy: 0.9722
# Epoch 25/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.1599 - accuracy: 0.9739
# Epoch 26/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.1499 - accuracy: 0.9755
# Epoch 27/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.1406 - accuracy: 0.9776
# Epoch 28/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1315 - accuracy: 0.9793
# Epoch 29/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.1245 - accuracy: 0.9806
# Epoch 30/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.1164 - accuracy: 0.9822
# Epoch 31/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.1103 - accuracy: 0.9831
# Epoch 32/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.1033 - accuracy: 0.9846
# Epoch 33/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0971 - accuracy: 0.9857
# Epoch 34/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0921 - accuracy: 0.9868
# Epoch 35/200
# 80/80 [==============================] - 5s 65ms/step - loss: 0.0850 - accuracy: 0.9880
# Epoch 36/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0796 - accuracy: 0.9891
# Epoch 37/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0750 - accuracy: 0.9897
# Epoch 38/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0696 - accuracy: 0.9912
# Epoch 39/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0652 - accuracy: 0.9919
# Epoch 40/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0611 - accuracy: 0.9929
# Epoch 41/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0575 - accuracy: 0.9943
# Epoch 42/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0529 - accuracy: 0.9960
# Epoch 43/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.0493 - accuracy: 0.9968
# Epoch 44/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0459 - accuracy: 0.9975
# Epoch 45/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0429 - accuracy: 0.9979
# Epoch 46/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0397 - accuracy: 0.9987
# Epoch 47/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0372 - accuracy: 0.9993
# Epoch 48/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0344 - accuracy: 0.9997
# Epoch 49/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0321 - accuracy: 0.9997
# Epoch 50/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0295 - accuracy: 0.9997
# Epoch 51/200
# 80/80 [==============================] - 5s 67ms/step - loss: 0.0277 - accuracy: 0.9999
# Epoch 52/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0256 - accuracy: 0.9999
# Epoch 53/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.0243 - accuracy: 0.9999
# Epoch 54/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 55/200
# 80/80 [==============================] - 5s 67ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 56/200
# 80/80 [==============================] - 5s 67ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 57/200
# 80/80 [==============================] - 5s 65ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 58/200
# 80/80 [==============================] - 5s 67ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 59/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 60/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 61/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 62/200
# 80/80 [==============================] - 5s 65ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 63/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 64/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 65/200
# 80/80 [==============================] - 5s 68ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 66/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 67/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 68/200
# 80/80 [==============================] - 6s 70ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 69/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 70/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 71/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 72/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 73/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 74/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 75/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 76/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 77/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 78/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 79/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 80/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 81/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 82/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 83/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 84/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 85/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 86/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 87/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 88/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 89/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 90/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 91/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 92/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 93/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 94/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 95/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 96/200
# 80/80 [==============================] - 5s 67ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 97/200
# 80/80 [==============================] - 6s 71ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 98/200
# 80/80 [==============================] - 6s 78ms/step - loss: 9.7286e-04 - accuracy: 1.0000
# Epoch 99/200
# 80/80 [==============================] - 6s 77ms/step - loss: 9.2618e-04 - accuracy: 1.0000
# Epoch 100/200
# 80/80 [==============================] - 5s 65ms/step - loss: 8.7402e-04 - accuracy: 1.0000
# Epoch 101/200
# 80/80 [==============================] - 5s 61ms/step - loss: 8.2794e-04 - accuracy: 1.0000
# Epoch 102/200
# 80/80 [==============================] - 5s 65ms/step - loss: 7.9073e-04 - accuracy: 1.0000
# Epoch 103/200
# 80/80 [==============================] - 5s 63ms/step - loss: 7.5932e-04 - accuracy: 1.0000
# Epoch 104/200
# 80/80 [==============================] - 5s 67ms/step - loss: 7.1424e-04 - accuracy: 1.0000
# Epoch 105/200
# 80/80 [==============================] - 5s 65ms/step - loss: 6.7728e-04 - accuracy: 1.0000
# Epoch 106/200
# 80/80 [==============================] - 5s 60ms/step - loss: 6.4610e-04 - accuracy: 1.0000
# Epoch 107/200
# 80/80 [==============================] - 5s 62ms/step - loss: 6.1756e-04 - accuracy: 1.0000
# Epoch 108/200
# 80/80 [==============================] - 5s 63ms/step - loss: 5.8416e-04 - accuracy: 1.0000
# Epoch 109/200
# 80/80 [==============================] - 5s 67ms/step - loss: 5.5446e-04 - accuracy: 1.0000
# Epoch 110/200
# 80/80 [==============================] - 6s 70ms/step - loss: 5.3771e-04 - accuracy: 1.0000
# Epoch 111/200
# 80/80 [==============================] - 5s 66ms/step - loss: 5.0762e-04 - accuracy: 1.0000
# Epoch 112/200
# 80/80 [==============================] - 5s 63ms/step - loss: 4.7695e-04 - accuracy: 1.0000
# Epoch 113/200
# 80/80 [==============================] - 5s 62ms/step - loss: 4.5247e-04 - accuracy: 1.0000
# Epoch 114/200
# 80/80 [==============================] - 5s 62ms/step - loss: 4.3219e-04 - accuracy: 1.0000
# Epoch 115/200
# 80/80 [==============================] - 5s 63ms/step - loss: 4.1300e-04 - accuracy: 1.0000
# Epoch 116/200
# 80/80 [==============================] - 5s 65ms/step - loss: 3.9088e-04 - accuracy: 1.0000
# Epoch 117/200
# 80/80 [==============================] - 6s 72ms/step - loss: 3.7344e-04 - accuracy: 1.0000
# Epoch 118/200
# 80/80 [==============================] - 6s 71ms/step - loss: 3.5542e-04 - accuracy: 1.0000
# Epoch 119/200
# 80/80 [==============================] - 6s 70ms/step - loss: 3.4106e-04 - accuracy: 1.0000
# Epoch 120/200
# 80/80 [==============================] - 5s 66ms/step - loss: 3.2443e-04 - accuracy: 1.0000
# Epoch 121/200
# 80/80 [==============================] - 5s 64ms/step - loss: 3.0848e-04 - accuracy: 1.0000
# Epoch 122/200
# 80/80 [==============================] - 5s 66ms/step - loss: 2.9668e-04 - accuracy: 1.0000
# Epoch 123/200
# 80/80 [==============================] - 5s 66ms/step - loss: 2.8527e-04 - accuracy: 1.0000
# Epoch 124/200
# 80/80 [==============================] - 5s 69ms/step - loss: 2.7145e-04 - accuracy: 1.0000
# Epoch 125/200
# 80/80 [==============================] - 6s 71ms/step - loss: 2.5622e-04 - accuracy: 1.0000
# Epoch 126/200
# 80/80 [==============================] - 6s 71ms/step - loss: 2.4420e-04 - accuracy: 1.0000
# Epoch 127/200
# 80/80 [==============================] - 5s 68ms/step - loss: 2.3308e-04 - accuracy: 1.0000
# Epoch 128/200
# 80/80 [==============================] - 6s 69ms/step - loss: 2.2098e-04 - accuracy: 1.0000
# Epoch 129/200
# 80/80 [==============================] - 6s 70ms/step - loss: 2.0972e-04 - accuracy: 1.0000
# Epoch 130/200
# 80/80 [==============================] - 5s 67ms/step - loss: 1.9973e-04 - accuracy: 1.0000
# Epoch 131/200
# 80/80 [==============================] - 5s 68ms/step - loss: 1.9033e-04 - accuracy: 1.0000
# Epoch 132/200
# 80/80 [==============================] - 5s 67ms/step - loss: 1.8159e-04 - accuracy: 1.0000
# Epoch 133/200
# 80/80 [==============================] - 5s 63ms/step - loss: 1.7398e-04 - accuracy: 1.0000
# Epoch 134/200
# 80/80 [==============================] - 5s 65ms/step - loss: 1.6686e-04 - accuracy: 1.0000
# Epoch 135/200
# 80/80 [==============================] - 5s 64ms/step - loss: 1.5983e-04 - accuracy: 1.0000
# Epoch 136/200
# 80/80 [==============================] - 5s 64ms/step - loss: 1.5384e-04 - accuracy: 1.0000
# Epoch 137/200
# 80/80 [==============================] - 5s 64ms/step - loss: 1.4609e-04 - accuracy: 1.0000
# Epoch 138/200
# 80/80 [==============================] - 5s 66ms/step - loss: 1.4508e-04 - accuracy: 1.0000
# Epoch 139/200
# 80/80 [==============================] - 5s 64ms/step - loss: 1.3730e-04 - accuracy: 1.0000
# Epoch 140/200
# 80/80 [==============================] - 5s 68ms/step - loss: 1.2968e-04 - accuracy: 1.0000
# Epoch 141/200
# 80/80 [==============================] - 5s 67ms/step - loss: 1.2328e-04 - accuracy: 1.0000
# Epoch 142/200
# 80/80 [==============================] - 5s 65ms/step - loss: 1.1885e-04 - accuracy: 1.0000
# Epoch 143/200
# 80/80 [==============================] - 5s 66ms/step - loss: 1.1335e-04 - accuracy: 1.0000
# Epoch 144/200
# 80/80 [==============================] - 5s 67ms/step - loss: 1.2676e-04 - accuracy: 1.0000
# Epoch 145/200
# 80/80 [==============================] - 5s 68ms/step - loss: 0.0318 - accuracy: 0.9924
# Epoch 146/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.0057 - accuracy: 0.9990
# Epoch 147/200
# 80/80 [==============================] - 5s 65ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 148/200
# 80/80 [==============================] - 5s 64ms/step - loss: 4.5326e-04 - accuracy: 1.0000
# Epoch 149/200
# 80/80 [==============================] - 5s 67ms/step - loss: 3.4574e-04 - accuracy: 1.0000
# Epoch 150/200
# 80/80 [==============================] - 5s 64ms/step - loss: 3.0326e-04 - accuracy: 1.0000
# Epoch 151/200
# 80/80 [==============================] - 5s 65ms/step - loss: 2.7445e-04 - accuracy: 1.0000
# Epoch 152/200
# 80/80 [==============================] - 5s 64ms/step - loss: 2.5130e-04 - accuracy: 1.0000
# Epoch 153/200
# 80/80 [==============================] - 5s 66ms/step - loss: 2.3304e-04 - accuracy: 1.0000
# Epoch 154/200
# 80/80 [==============================] - 5s 65ms/step - loss: 2.1740e-04 - accuracy: 1.0000
# Epoch 155/200
# 80/80 [==============================] - 5s 63ms/step - loss: 2.0428e-04 - accuracy: 1.0000
# Epoch 156/200
# 80/80 [==============================] - 5s 66ms/step - loss: 1.9244e-04 - accuracy: 1.0000
# Epoch 157/200
# 80/80 [==============================] - 5s 65ms/step - loss: 1.8169e-04 - accuracy: 1.0000
# Epoch 158/200
# 80/80 [==============================] - 5s 64ms/step - loss: 1.7231e-04 - accuracy: 1.0000
# Epoch 159/200
# 80/80 [==============================] - 5s 64ms/step - loss: 1.6352e-04 - accuracy: 1.0000
# Epoch 160/200
# 80/80 [==============================] - 5s 63ms/step - loss: 1.5550e-04 - accuracy: 1.0000
# Epoch 161/200
# 80/80 [==============================] - 5s 61ms/step - loss: 1.4823e-04 - accuracy: 1.0000
# Epoch 162/200
# 80/80 [==============================] - 5s 65ms/step - loss: 1.4143e-04 - accuracy: 1.0000
# Epoch 163/200
# 80/80 [==============================] - 5s 64ms/step - loss: 1.3520e-04 - accuracy: 1.0000
# Epoch 164/200
# 80/80 [==============================] - 5s 63ms/step - loss: 1.2927e-04 - accuracy: 1.0000
# Epoch 165/200
# 80/80 [==============================] - 5s 66ms/step - loss: 1.2388e-04 - accuracy: 1.0000
# Epoch 166/200
# 80/80 [==============================] - 5s 66ms/step - loss: 1.1869e-04 - accuracy: 1.0000
# Epoch 167/200
# 80/80 [==============================] - 5s 68ms/step - loss: 1.1371e-04 - accuracy: 1.0000
# Epoch 168/200
# 80/80 [==============================] - 5s 63ms/step - loss: 1.0910e-04 - accuracy: 1.0000
# Epoch 169/200
# 80/80 [==============================] - 5s 64ms/step - loss: 1.0475e-04 - accuracy: 1.0000
# Epoch 170/200
# 80/80 [==============================] - 5s 63ms/step - loss: 1.0070e-04 - accuracy: 1.0000
# Epoch 171/200
# 80/80 [==============================] - 5s 65ms/step - loss: 9.6760e-05 - accuracy: 1.0000
# Epoch 172/200
# 80/80 [==============================] - 5s 66ms/step - loss: 9.3078e-05 - accuracy: 1.0000
# Epoch 173/200
# 80/80 [==============================] - 5s 65ms/step - loss: 8.9481e-05 - accuracy: 1.0000
# Epoch 174/200
# 80/80 [==============================] - 5s 65ms/step - loss: 8.6214e-05 - accuracy: 1.0000
# Epoch 175/200
# 80/80 [==============================] - 5s 61ms/step - loss: 8.2915e-05 - accuracy: 1.0000
# Epoch 176/200
# 80/80 [==============================] - 5s 65ms/step - loss: 7.9814e-05 - accuracy: 1.0000
# Epoch 177/200
# 80/80 [==============================] - 5s 63ms/step - loss: 7.6876e-05 - accuracy: 1.0000
# Epoch 178/200
# 80/80 [==============================] - 5s 64ms/step - loss: 7.4019e-05 - accuracy: 1.0000
# Epoch 179/200
# 80/80 [==============================] - 5s 64ms/step - loss: 7.1344e-05 - accuracy: 1.0000
# Epoch 180/200
# 80/80 [==============================] - 5s 63ms/step - loss: 6.8733e-05 - accuracy: 1.0000
# Epoch 181/200
# 80/80 [==============================] - 5s 64ms/step - loss: 6.6220e-05 - accuracy: 1.0000
# Epoch 182/200
# 80/80 [==============================] - 5s 66ms/step - loss: 6.3838e-05 - accuracy: 1.0000
# Epoch 183/200
# 80/80 [==============================] - 5s 64ms/step - loss: 6.1518e-05 - accuracy: 1.0000
# Epoch 184/200
# 80/80 [==============================] - 5s 65ms/step - loss: 5.9282e-05 - accuracy: 1.0000
# Epoch 185/200
# 80/80 [==============================] - 5s 64ms/step - loss: 5.7148e-05 - accuracy: 1.0000
# Epoch 186/200
# 80/80 [==============================] - 5s 64ms/step - loss: 5.5057e-05 - accuracy: 1.0000
# Epoch 187/200
# 80/80 [==============================] - 5s 66ms/step - loss: 5.3114e-05 - accuracy: 1.0000
# Epoch 188/200
# 80/80 [==============================] - 6s 71ms/step - loss: 5.1217e-05 - accuracy: 1.0000
# Epoch 189/200
# 80/80 [==============================] - 5s 63ms/step - loss: 4.9369e-05 - accuracy: 1.0000
# Epoch 190/200
# 80/80 [==============================] - 5s 63ms/step - loss: 4.7563e-05 - accuracy: 1.0000
# Epoch 191/200
# 80/80 [==============================] - 5s 59ms/step - loss: 4.5872e-05 - accuracy: 1.0000
# Epoch 192/200
# 80/80 [==============================] - 5s 61ms/step - loss: 4.4244e-05 - accuracy: 1.0000
# Epoch 193/200
# 80/80 [==============================] - 5s 61ms/step - loss: 4.2653e-05 - accuracy: 1.0000
# Epoch 194/200
# 80/80 [==============================] - 5s 62ms/step - loss: 4.1118e-05 - accuracy: 1.0000
# Epoch 195/200
# 80/80 [==============================] - 5s 63ms/step - loss: 3.9632e-05 - accuracy: 1.0000
# Epoch 196/200
# 80/80 [==============================] - 5s 64ms/step - loss: 3.8234e-05 - accuracy: 1.0000
# Epoch 197/200
# 80/80 [==============================] - 6s 69ms/step - loss: 3.6829e-05 - accuracy: 1.0000
# Epoch 198/200
# 80/80 [==============================] - 5s 59ms/step - loss: 3.5529e-05 - accuracy: 1.0000
# Epoch 199/200
# 80/80 [==============================] - 5s 62ms/step - loss: 3.4255e-05 - accuracy: 1.0000
# Epoch 200/200
# 80/80 [==============================] - 5s 67ms/step - loss: 3.3003e-05 - accuracy: 1.0000
